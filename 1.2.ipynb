# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
import scipy.ndimage as ndi
data=iio.imread("fruit.jpg",mode="F")
bdata=ndi.shift(data,shift=(100,25))
plt.imshow(bdata)
plt.show()
