# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as iio
import scipy.ndimage as ndi
data=iio.imread('fruit.jpg')
print(data.shape)
bdata=ndi.zoom(data,2.0)
print(bdata.shape)
data2 = ndi.zoom(data, (2, 2, 1))
print(data2.shape)
data3=ndi.zoom(data,(0.5,0.9,1.0))
plt.imshow(data3)
plt.show()
# Out:
# (1427, 2100, 3)
# (2854, 4200, 6)
# (2854, 4200, 3)
